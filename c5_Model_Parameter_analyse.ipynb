# %%
# dowaload the packge if needed
! pip install pandas numpy matplotlib statsmodels
# Out:
# Requirement already satisfied: pandas in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: numpy in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: matplotlib in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: statsmodels in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: patsy>=0.5.6 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in /Users/zhangzhenlong/.pyenv/versions/3.9.6/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# session level paramater analyse
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf


CSV_PATH = 'rlddm_section_results_fminunc.csv'
female_color = '#D55672'
male_color = '#0075A2'
femaleIDs = {'rat150','rat152','rat224','rat225','rat228'}


def add_sex(df):
    return df.assign(sex=df['ratID'].apply(lambda r: 'female' if r in femaleIDs else 'male'))

def permutation_test(group1, group2, n_perm=100000, seed=42):
    np.random.seed(seed)
    group1, group2 = np.array(group1), np.array(group2)
    observed = np.mean(group1) - np.mean(group2)
    combined = np.concatenate([group1, group2])
    count = 0
    for _ in range(n_perm):
        np.random.shuffle(combined)
        perm1 = combined[:len(group1)]
        perm2 = combined[len(group1):]
        diff = np.mean(perm1) - np.mean(perm2)
        if abs(diff) >= abs(observed):
            count += 1
    p_value = count / n_perm
    return observed, p_value


def plot_param_permutation(df, param_name, ylabel, title, use_abs=False):
    if use_abs:
        df[param_name] = df[param_name].abs()

    is_male = df["sex"] == "male"
    is_female = df["sex"] == "female"

    k_male = df.loc[is_male, param_name].values
    k_female = df.loc[is_female, param_name].values

    # ====== Permutation test ======
    obs_diff, p_val = permutation_test(k_male, k_female)
    print(f"[{param_name}] Permutation observed diff = {obs_diff:.4f}, p = {p_val:.4f}")

    # ====== Boxplot only ======
    fig, ax = plt.subplots(figsize=(2, 2), dpi=400)
    groups = [k_male, k_female]
    bp = ax.boxplot(groups, patch_artist=True, widths=0.5, showfliers=False,
                    boxprops=dict(facecolor='white', linewidth=1.5),
                    medianprops=dict(linewidth=1.5),
                    whiskerprops=dict(linewidth=1.5),
                    capprops=dict(linewidth=1.5))
    
    for i, color in enumerate([male_color, female_color]):
        bp['boxes'][i].set_edgecolor(color)
        bp['whiskers'][2*i].set_color(color)
        bp['whiskers'][2*i+1].set_color(color)
        bp['caps'][2*i].set_color(color)
        bp['caps'][2*i+1].set_color(color)
        bp['medians'][i].set_color(color)

    ax.set_xticks([1, 2])
    ax.set_xticklabels(['Male', 'Female'])
    ax.set_ylabel(ylabel)
    ax.set_title(title, fontsize=10)

    
    stars = ''
    if p_val < 0.001: stars = '***'
    elif p_val < 0.01: stars = '**'
    elif p_val < 0.05: stars = '*'

    if stars:
        ymin, ymax = ax.get_ylim()
        y_star = ymax - 0.15 * (ymax - ymin)
        ax.text(1.5, y_star, stars, ha='center', va='center', fontsize=12)

    plt.tight_layout()
    plt.show()
    
def plot_w_4group(df):
    df = df.dropna(subset=['w']).copy()
    df['group'] = df.apply(lambda row: 
        f"{'Male' if row['ratID'] not in femaleIDs else 'Female'}-" + 
        ("Satiety" if row['w'] < 0 else "Reward"), axis=1)

    group_order = ['Male-Reward', 'Female-Reward', 'Male-Satiety', 'Female-Satiety']
    colors = [male_color, female_color, male_color, female_color]

    fig, ax = plt.subplots(figsize=(3, 2.2), dpi=400)
    group_data = [df[df['group'] == g]['w'].abs() for g in group_order]
    bp = ax.boxplot(group_data, patch_artist=True, widths=0.5, showfliers=False,
                    boxprops=dict(facecolor='white', linewidth=1.5),
                    medianprops=dict(linewidth=1.5),
                    whiskerprops=dict(linewidth=1.5),
                    capprops=dict(linewidth=1.5))
    
    for i in range(4):
        c = colors[i]
        bp['boxes'][i].set_edgecolor(c)
        bp['whiskers'][2*i].set_color(c)
        bp['whiskers'][2*i+1].set_color(c)
        bp['caps'][2*i].set_color(c)
        bp['caps'][2*i+1].set_color(c)
        bp['medians'][i].set_color(c)

    # ===== permutation test =====
    obs1, p1 = permutation_test(group_data[0], group_data[1])  # Reward
    obs2, p2 = permutation_test(group_data[2], group_data[3])  # Satiety
    print(f"[Reward] Observed diff: {obs1:.4f}, Permutation p = {p1:.4f}")
    print(f"[Satiety] Observed diff: {obs2:.4f}, Permutation p = {p2:.4f}")

    
    def get_stars(p):
        if p < 0.001: return '***'
        elif p < 0.01: return '**'
        elif p < 0.05: return '*'
        else: return ''

    star1 = get_stars(p1)
    star2 = get_stars(p2)

    ax.set_xticks(range(1, 5))
    ax.set_xticklabels(group_order, rotation=15)
    ax.set_ylabel("|w|")
    ax.set_title("Boundary Modulation w by Sex & Type")

    
    y_top = ax.get_ylim()[1]
    y_star = y_top * 0.85 

    if star1:
        ax.text(1.5, y_star, star1, ha='center', fontsize=12)
    if star2:
        ax.text(3.5, y_star, star2, ha='center', fontsize=12)

    plt.tight_layout()
    plt.show()



if __name__ == "__main__":
    df = pd.read_csv(CSV_PATH)
    df = add_sex(df)

    plot_param_permutation(df, 'k', 'Scaling Factor k', 'k by Sex', use_abs=False)
    plot_param_permutation(df, 'a', 'Boundary a', 'a by Sex', use_abs=False)
    plot_param_permutation(df, 'w', 'Boundary Modulation w', 'w by Sex', use_abs=False)
    plot_w_4group(df)
# Out:
# [k] Permutation observed diff = 0.5656, p = 0.0000
# [a] Permutation observed diff = -48.4889, p = 0.0000
# [w] Permutation observed diff = -0.1373, p = 0.0393
# [Reward] Observed diff: -0.1953, Permutation p = 0.0001
# [Satiety] Observed diff: -0.5585, Permutation p = 0.0001
